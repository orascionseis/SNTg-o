# %% [markdown]
# ## Bonjour voici un premier exemple de code

# %% [markdown]
# # Petit titre

# %% [markdown]
# Utilisez la commande print pour afficher le mot "bonjour"

# %%
print("bonjour")
# Out:
# bonjour
